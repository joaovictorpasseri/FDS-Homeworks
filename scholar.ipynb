# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
import time

# %%
url = "http://scholar.google.com.br/"
autor = 'Daniele Passeri' 
#page = urllib.request.urlopen(url)

# %%
driver = webdriver.Chrome()
driver.get(url)
driver.implicitly_wait(100)

# %%
entrada_autor = driver.find_element_by_id("gs_hdr_tsi")
entrada_autor.send_keys(autor)
clicar = driver.find_element_by_id('gs_hdr_tsb')
clicar.click()

# %%
continue_link = driver.find_element_by_link_text(autor)
continue_link.click()

# %%
mostrar_mais = driver.find_element_by_id('gsc_bpf_more')
x = mostrar_mais.get_property('disabled')==False

# %%
while x:
    mostrar_mais.click()
    time.sleep(2)
    x = mostrar_mais.get_property('disabled')==False

# %%
html = BeautifulSoup(driver.page_source)

# %%
tabela = html.find('table',{'id':'gsc_a_t'})
papers = []
trabalhos = tabela.find_all('td',{"class":'gsc_a_t'})
for trabalhos in tabela.find_all('td',{"class":'gsc_a_t'}):
    titulo = trabalhos.find('a')
    titulo = titulo.contents[0]
    autores = trabalhos.find('div',{'class':'gs_gray'})
    autores = autores.contents[0].split(',')    
    autores = [i.strip() for i in autores]
    if autores[-1]=='...':
        autores.pop()
    papers.append({'title':titulo,'authors':autores})

# %%
driver.quit()
print(papers)
# Out:
# [{'title': 'Observation of a new boson at a mass of 125 GeV with the CMS experiment at the LHC', 'authors': ['S Chatrchyan', 'V Khachatryan', 'AM Sirunyan', 'A Tumasyan', 'W Adam']}, {'title': 'The CMS experiment at the CERN LHC', 'authors': ['S Chatrchyan', 'EA de Wolf']}, {'title': 'CMS physics technical design report, volume II: physics performance', 'authors': ['CMS collaboration']}, {'title': 'Description and performance of track and primary-vertex reconstruction with the CMS tracker', 'authors': ['CMS collaboration']}, {'title': 'CMS Physics: Technical Design Report Volume 2: Physics Performance', 'authors': ['GL Bayatian', 'A Korablev', 'A Soha', 'O Sharif', 'M Chertok', 'W Mitaroff']}, {'title': 'Radiation hard silicon detectors—developments by the RD48 (ROSE) collaboration', 'authors': ['G Lindström', 'M Ahmed', 'S Albergo', 'P Allport', 'D Anderson', 'L Andricek']}, {'title': 'CMS physics: Technical design report', 'authors': ['GL Bayatian', 'S Chatrchyan', 'G Hmayakyan', 'AM Sirunyan', 'W Adam']}, {'title': 'CMS physics technical design report: Addendum on high density QCD with heavy ions', 'authors': ["D d'Enterria", 'M Ballintijn', 'M Bedjidian', 'D Hofman', 'O Kodolova', 'C Loizides']}, {'title': 'CMS Physics: Technical Design Report Volume 1: Detector Performance and Software', 'authors': ['GL Bayatian', 'A Korablev', 'A Soha', 'O Sharif', 'M Chertok', 'W Mitaroff']}, {'title': 'A new boson with a mass of 125 GeV observed with the CMS experiment at the Large Hadron Collider', 'authors': ['CMS collaboration']}, {'title': 'CMS: the TriDAS Project Technical Design Report; v. 1, the Trigger Systems', 'authors': ['GL Bayatyan', 'N Grigorian', 'VG Khachatrian', 'AT Margarian', 'AM Sirunyan']}, {'title': 'CMS physics technical design report: Addendum on high density QCD with heavy ions', 'authors': ['CMS collaboration']}, {'title': 'Numerical simulation of radiation damage effects in p-type and n-type FZ silicon detectors', 'authors': ['M Petasecca', 'F Moscatelli', 'D Passeri', 'GU Pignatel']}, {'title': 'Alignment of the CMS tracker with LHC and cosmic ray data', 'authors': ['CMS collaboration']}, {'title': 'Radiation-hard semiconductor detectors for SuperLHC', 'authors': ['M Bruzzi', 'J Adey', 'A Al-Ajili', 'P Alexandrov', 'G Alfieri', 'PP Allport']}, {'title': 'Development of radiation tolerant semiconductor detectors for the Super-LHC', 'authors': ['M Moll', 'J Adey', 'A Al-Ajili', 'G Alfieri', 'PP Allport', 'M Artuso', 'S Assouak']}, {'title': 'Energy loss measurement for charged particles in very thin silicon layers', 'authors': ['S Meroli', 'D Passeri', 'L Servoli']}, {'title': 'Recent advancements in the development of radiation hard semiconductor detectors for S-LHC', 'authors': ['E Fretwurst', 'J Adey', 'A Al-Ajili', 'G Alfieri', 'PP Allport', 'M Artuso', 'S Assouak']}, {'title': 'Comprehensive modeling of bulk-damage effects in silicon radiation detectors', 'authors': ['D Passeri', 'P Ciampolini', 'GM Bilei', 'F Moscatelli']}, {'title': 'New results on silicon microstrip detectors of CMS tracker', 'authors': ['N Demaria', 'S Albergo', 'M Angarano', 'P Azzi', 'E Babucci', 'N Bacchetta']}, {'title': 'Numerical simulation of radiation damage effects in p-type silicon detectors', 'authors': ['M Petasecca', 'F Moscatelli', 'D Passeri', 'GU Pignatel', 'C Scarpello']}, {'title': 'Silicon detectors for the sLHC', 'authors': ['A Affolder', 'A Aleev', 'PP Allport', 'L Andricek', 'M Artuso', 'JP Balbuena']}, {'title': 'Separating polarized cosmological and galactic emissions for cosmic microwave background B-mode polarization experiments', 'authors': ['F Stivoli', 'C Baccigalupi', 'D Maino', 'R Stompor']}, {'title': 'Solid anaerobic digestion batch with liquid digestate recirculation and wet anaerobic digestion of organic waste: Comparison of system performances and identification of\xa0…', 'authors': ['F Di Maria', 'M Barratta', 'F Bianconi', 'P Placidi', 'D Passeri']}, {'title': 'Characterization of standard CMOS pi ...
